# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/ApplicantProject.csv')
df
# Out:
#        Number      Created Date  Priority                 Account  \
# 0     CS96304    1/1/20 2:30 AM  Very Low  Random AccountName 142
# 1     CS71638    1/2/20 7:10 PM      High  Random AccountName 154
# 2     CS44369    1/4/20 4:50 AM      High  Random AccountName 127
# 3     CS61103    1/5/20 2:01 AM  Critical  Random AccountName 179
# 4     CS67928    1/5/20 3:08 AM      High  Random AccountName 115
# ...       ...               ...       ...                     ...
# 2052  CS88712  7/23/23 10:13 AM  Critical  Random AccountName 149
# 2053  CS33799   7/23/23 9:52 PM  Critical   Random AccountName 25
# 2054  CS69674  7/25/23 12:17 AM  Very Low  Random AccountName 226
# 2055  CS80200   7/26/23 5:29 PM       Low  Random AccountName 119
# 2056  CS96284  7/28/23 11:21 AM      High  Random AccountName 165
#
#                   ACV   Upcoming ACV Opportunities   AccountCountry  \
# 0      $10,125,545.34                 $(121,800.28)  United Kingdom
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.dtypes
# Out:
# Number                          object
# Created Date                    object
# Priority                        object
# Account                         object
#  ACV                            object
#  Upcoming ACV Opportunities     object
# AccountCountry                  object
# AccountIndustry                 object
# Created Month                   object
# InquiryType                     object
# dtype: object

# %%
# rename columns so they don't have spaces (bad formatting)
df = df.rename(columns = {'Created Date': 'CreatedDate', ' ACV ':'ACV', ' Upcoming ACV Opportunities ':'UpcomingACVOpportunities', 'Created Month':'CreatedMonth'})

# %%
df.dtypes
# Out:
# Number                      object
# CreatedDate                 object
# Priority                    object
# Account                     object
# ACV                         object
# UpcomingACVOpportunities    object
# AccountCountry              object
# AccountIndustry             object
# CreatedMonth                object
# InquiryType                 object
# dtype: object

# %%
# convert date to datetime object 
df['CreatedDate'] = pd.to_datetime(df['CreatedDate'])
df['CreatedMonth'] = df['CreatedDate'].dt.strftime('%Y-%m')

# %%
# convert account number to just the number 
df['Account'] = df['Account'].apply(lambda x: x.split(' ')[-1])

# %%
# convert ACV and Upcoming ACV to number instead of strings 
df['ACV'] = df['ACV'].replace('[\$,]', '', regex=True).astype(float)
df['UpcomingACVOpportunities'] = pd.to_numeric(df['UpcomingACVOpportunities'].str.replace('[\$,]', '', regex=True).replace(r'\(', '-', regex=True).replace(r'\)', '', regex=True))

# %%
df.to_csv('data/cleaned.csv')

# %% [markdown]
# # Summary Statistics

# %%
df.head()
# Out:
#     Number         CreatedDate  Priority Account          ACV  \
# 0  CS96304 2020-01-01 02:30:00  Very Low     142  10125545.34
# 1  CS71638 2020-01-02 19:10:00      High     154    873271.83
# 2  CS44369 2020-01-04 04:50:00      High     127  11961103.07
# 3  CS61103 2020-01-05 02:01:00  Critical     179  64658626.07
# 4  CS67928 2020-01-05 03:08:00      High     115  16274282.36
#
#    UpcomingACVOpportunities  AccountCountry       AccountIndustry  \
# 0                -121800.28  United Kingdom              Retailer
# 1                 159409.06          Mexico  Information Security
# 2                2752627.26          Mexico  Information Security
# 3                  47779.11          Canada            Technology
# 4                 377871.90           Japan  Information Security
#
#   CreatedMonth                 InquiryType
# 0      2020-01  Question about the product
# 1      2020-01  Question about the product
# 2      2020-01  Question about the product
# ...

# %%
# check if Number column has unique values 
df['Number'].value_counts().hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Very few duplicate number values -> look into which ones are duplicated

# %%
df[df.duplicated('Number', keep=False)].sort_values(by = 'Number')
# Out:
#        Number         CreatedDate  Priority Account          ACV  \
# 147   CS11864 2020-05-25 08:05:00  Critical     129  39265316.11
# 763   CS11864 2022-02-11 03:37:00  Critical     149  39219548.74
# 2015  CS13766 2023-06-23 21:29:00  Critical     176  37687729.63
# 297   CS13766 2020-10-22 12:29:00  Critical     217   6933203.35
# 497   CS14413 2021-05-23 03:30:00    Medium     113  16941362.05
# 619   CS14413 2021-09-19 19:03:00  Very Low     155  10950966.82
# 1884  CS19407 2023-05-05 01:38:00  Critical     181  16699602.25
# 1311  CS19407 2023-03-10 12:35:00    Medium     155  10950966.82
# 1767  CS22138 2023-04-04 00:07:00  Very Low     170   4134839.56
# 1672  CS22138 2023-03-18 08:26:00       Low      48   6091837.52
# 1973  CS27843 2023-06-04 18:20:00      High     168  70673688.75
# 223   CS27843 2020-08-04 03:33:00  Critical      94  12092157.80
# 15    CS28891 2020-01-17 12:38:00  Very Low     211  37074604.61
# ...

# %%
df[df.duplicated('Account', keep=False)].sort_values(by = 'Account')
# Out:
#        Number         CreatedDate  Priority Account          ACV  \
# 62    CS12124 2020-03-02 17:36:00       Low       1  40003737.93
# 887   CS62567 2022-06-10 11:46:00  Critical       1  40003737.93
# 1689  CS28366 2023-03-19 00:32:00       Low       1  40003737.93
# 1381  CS18142 2023-03-11 13:34:00  Critical       1  40003737.93
# 2046  CS19616 2023-07-17 20:46:00       Low       1  40003737.93
# ...       ...                 ...       ...     ...          ...
# 1805  CS96772 2023-04-13 20:18:00  Critical      99   2049471.40
# 193   CS42500 2020-07-05 12:46:00  Very Low      99   2049471.40
# 486   CS84882 2021-05-10 21:08:00  Very Low      99   2049471.40
# 1898  CS85818 2023-05-08 21:27:00    Medium      99   2049471.40
# 1518  CS29497 2023-03-13 19:47:00       Low      99   2049471.40
#
#       UpcomingACVOpportunities AccountCountry AccountIndustry CreatedMonth  \
# 62                    86165.85         Mexico         Finance      2020-03
# ...

# %% [markdown]
# Here we see it is possible for the same account to have different cases, countries, and industries -> meaning it represents different companies that the same case can be -> overall would be an inconsistency issue I would bring up but for this case it doesn't matter

# %%
# Check distribution of priority values 
df['Priority'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Seems like a balanced dataset for priority values

# %%
# Analyze distributions of ACV columns 
df.describe()
# Out:
#                 ACV  UpcomingACVOpportunities
# count  2.057000e+03              2.057000e+03
# mean   2.111781e+07              7.426303e+05
# std    1.811208e+07              9.845805e+05
# min    8.007830e+03             -7.710434e+05
# 25%    6.933203e+06              4.028471e+04
# 50%    1.517604e+07              4.636800e+05
# 75%    3.339220e+07              1.283994e+06
# max    7.698662e+07              3.913133e+06

# %%
# check for any outliers with ACV 
q1 = df['ACV'].quantile(0.25)
q3 = df['ACV'].quantile(0.75)

iqr = q3 - q1

lower = q1 - 1.5 * iqr
upper = q3 + 1.5 * iqr

outliers = df[(df['ACV'] < lower) | (df['ACV'] > upper)]
outliers
# Out:
#        Number         CreatedDate  Priority Account          ACV  \
# 75    CS32524 2020-03-13 16:51:00  Very Low     173  75431069.94
# 322   CS67852 2020-11-20 00:34:00  Critical      58  76986619.94
# 502   CS48928 2021-05-26 08:09:00  Critical     173  75431069.94
# 504   CS36115 2021-05-28 10:09:00    Medium     258  73097514.04
# 540   CS40106 2021-07-04 18:00:00  Critical     194  74880571.68
# 560   CS76960 2021-07-22 02:04:00  Critical      58  76986619.94
# 596   CS32792 2021-08-27 12:36:00    Medium     258  73097514.04
# 617   CS35393 2021-09-17 08:27:00  Very Low      58  76986619.94
# 697   CS38210 2021-12-02 02:23:00  Critical     173  75431069.94
# 727   CS16217 2021-12-31 14:42:00  Critical     194  74880571.68
# 793   CS24498 2022-03-09 12:20:00  Very Low     194  74880571.68
# 812   CS44990 2022-03-31 11:15:00  Critical     194  74880571.68
# 818   CS26463 2022-04-07 21:50:00    Medium     173  75431069.94
# ...

# %%
outliers.shape
# Out:
# (21, 10)

# %%
df[df['CreatedMonth']=='2021-04']
# Out:
#       Number         CreatedDate  Priority Account          ACV  \
# 447  CS44708 2021-04-01 01:36:00       Low     222   7102972.97
# 448  CS36838 2021-04-01 20:32:00      High      19   9586206.09
# 449  CS13594 2021-04-03 00:38:00  Very Low     232  11860230.78
# 450  CS45643 2021-04-04 23:07:00  Critical      16  17494755.67
# 451  CS83721 2021-04-06 08:09:00  Very Low     256  31922945.43
# 452  CS22452 2021-04-06 15:40:00  Very Low     222   7102972.97
# 453  CS26636 2021-04-06 19:11:00      High     223   5324537.13
# 454  CS21284 2021-04-08 07:02:00    Medium      88  63032490.02
# 455  CS87644 2021-04-08 13:19:00  Critical      84  42771455.72
# 456  CS65358 2021-04-09 00:44:00       Low     254  12234653.83
# 457  CS77959 2021-04-10 14:52:00       Low     107   6294174.96
# 458  CS65847 2021-04-11 23:19:00       Low     169  16951501.28
# 459  CS99125 2021-04-13 19:49:00  Very Low      56   2841857.19
# 460  CS17307 2021-04-14 06:23:00    Medium       8  20258865.73
# ...

# %%
# check for any outliers with UpcomingACV 
q1 = df['UpcomingACVOpportunities'].quantile(0.25)
q3 = df['UpcomingACVOpportunities'].quantile(0.75)

iqr = q3 - q1

lower = q1 - 1.5 * iqr
upper = q3 + 1.5 * iqr

outliers = df[(df['UpcomingACVOpportunities'] < lower) | (df['UpcomingACVOpportunities'] > upper)]
outliers
# Out:
#        Number         CreatedDate  Priority Account          ACV  \
# 16    CS48307 2020-01-19 09:51:00      High       8  20258865.73
# 18    CS33189 2020-01-20 09:08:00  Critical     259  52744687.25
# 24    CS94701 2020-01-24 08:41:00  Critical     187   3231392.81
# 32    CS16462 2020-02-03 00:14:00  Critical     230  26043027.58
# 42    CS49401 2020-02-11 22:41:00    Medium     139  29558682.21
# ...       ...                 ...       ...     ...          ...
# 1968  CS48527 2023-06-03 05:06:00  Very Low     187   3231392.81
# 2022  CS32920 2023-06-27 09:21:00  Very Low     259  52744687.25
# 2030  CS74229 2023-07-04 09:30:00    Medium     230  26043027.58
# 2037  CS20147 2023-07-10 03:52:00       Low     187   3231392.81
# 2042  CS22082 2023-07-16 01:11:00       Low     259  52744687.25
#
#       UpcomingACVOpportunities AccountCountry       AccountIndustry  \
# 16                  3238714.34         Norway               Finance
# ...

# %%
outliers['CreatedMonth'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
outliers[outliers['CreatedMonth']=='2023-03']
# Out:
#        Number         CreatedDate  Priority Account          ACV  \
# 1216  CS29893 2023-03-08 22:55:00      High       8  20258865.73
# 1235  CS57153 2023-03-09 08:58:00      High      53  21840037.93
# 1242  CS97695 2023-03-09 11:38:00  Critical     230  26043027.58
# 1266  CS40896 2023-03-09 20:38:00  Critical     259  52744687.25
# 1290  CS18814 2023-03-10 04:31:00      High     230  26043027.58
# 1361  CS62779 2023-03-11 05:48:00    Medium      53  21840037.93
# 1364  CS64360 2023-03-11 07:07:00    Medium     139  29558682.21
# 1380  CS69900 2023-03-11 13:20:00  Critical     230  26043027.58
# 1413  CS25262 2023-03-12 03:03:00    Medium       8  20258865.73
# 1450  CS20394 2023-03-12 18:03:00  Critical       8  20258865.73
# 1460  CS42494 2023-03-12 20:56:00    Medium     230  26043027.58
# 1474  CS56327 2023-03-13 02:01:00       Low       8  20258865.73
# 1530  CS59365 2023-03-13 22:55:00      High      53  21840037.93
# ...

# %%
# check distribution of AccountCountry
df['AccountCountry'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Well balanced dataset for locations as well -> if there is a certain country producing the most amount of ACV with cases it does not have to do with location size

# %%
# check distribution of AccountIndustry
df['AccountIndustry'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Almost twice as many accounts come from the public sector compared to any other industry -> just because outliers in march are associated with public sector industry doesn't mean that is a statistically significant correlation

# %%
# check distribution of months
df['CreatedMonth'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# March 2023 also has the highest # of cases created (almost 6 times as many!!) -> something must have happened with a product or technical outage etc in that time to have caused so many cases and thus increase the amount of ACV

# %%
# check distribution of InquiryType
df['InquiryType'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Decently balanced distribution of type of inquiry -> it's possible if security concerns are low that they rarely happen and maybe all of them happened in March due to security threat?

# %% [markdown]
# # March 2023 Data

# %%
spike = df[df['CreatedMonth']=='2023-03']
spike.head()
# Out:
#        Number         CreatedDate  Priority Account          ACV  \
# 1155  CS77753 2023-03-01 15:24:00  Very Low     253   1081342.70
# 1156  CS74694 2023-03-02 07:09:00    Medium       5  44456467.06
# 1157  CS33805 2023-03-02 11:54:00    Medium     130  17641667.39
# 1158  CS72569 2023-03-02 22:12:00  Very Low      97  23682497.08
# 1159  CS14827 2023-03-03 01:15:00       Low      99   2049471.40
#
#       UpcomingACVOpportunities  AccountCountry AccountIndustry CreatedMonth  \
# 1155                1563083.74  United Kingdom   Public Sector      2023-03
# 1156                1229902.33   United States   Public Sector      2023-03
# 1157                 815028.15  United Kingdom   Public Sector      2023-03
# 1158                1147889.55          Norway   Public Sector      2023-03
# 1159                -271582.04           Japan   Public Sector      2023-03
#
#                      InquiryType
# 1155  Question about the product
# 1156            Contract Support
# ...

# %%
# what does the priority of these cases look like in spike month 
spike['Priority'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Proportion of very low priority cases declined significantly compared to population distribution

# %%
# what does the country of these cases look like in spike month 
spike['AccountCountry'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Nothing weird with countries - looks like even distribution

# %%
# what does the industry of these cases look like in spike month 
spike['AccountIndustry'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Compared to population distribution this distribution looks the same - HOWEVER there are close to 350 public sector cases in this month compared to the 700 overall

# %%
# check industry distribution for another month 
df[df['CreatedMonth']=='2023-01']['AccountIndustry'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Completely different distribution with # of cases on y axis lower as well

# %%
# check inquiry type distribution for another month 
df[df['CreatedMonth']=='2023-01']['InquiryType'].value_counts().plot(kind='bar')                                                                                                                                                                                                                                                       # what does the inquiry type of these cases look like in spike month 
                                                                                                                                                                                                                                                                        spike['InquiryType'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# This distribution of inquiry types looks similar to overall distribution - however the # of security concern cases looks to be almost half of the overall security concern cases

# %%
def get_spike_props(col, condition):
    total_cases = df[df[col]==condition].shape[0]
    march_cases = df[(df[col]==condition) & (df['CreatedMonth']=='2023-03')].shape[0]
    return march_cases / total_cases

# %%
print(get_spike_props('InquiryType', 'Security Concern'))
print(get_spike_props('InquiryType', 'Contract Support'))
print(get_spike_props('InquiryType', 'Question about the product'))
print(get_spike_props('InquiryType', 'Issue with the product'))
# Out:
# 0.5531914893617021
# 0.28296296296296297
# 0.25673534072900156
# 0.25932504440497334

# %%
march_counts = spike[spike['CreatedMonth'] == '2023-03']['InquiryType'].value_counts()

percentages = []
for priority in march_counts.index:
    percentage = get_spike_props('InquiryType', priority) * 100
    percentages.append(percentage)

plot_data = pd.DataFrame({'March Counts': march_counts, 'March Percentage': percentages})


fig, ax1 = plt.subplots()

ax1.bar(plot_data.index, plot_data['March Counts'], color='blue', alpha=0.7, label='March Counts')
ax1.set_xlabel('Priority')
ax1.set_ylabel('Counts', color='blue')
ax1.tick_params('y', colors='blue')
ax1.set_title('March 2023 Cases by Priority Type and Percentage')

ax2 = ax1.twinx()
ax2.plot(plot_data.index, plot_data['March Percentage'], color='red', marker='o', label='March Percentage')
ax2.set_ylabel('Percentage', color='red')
ax2.tick_params('y', colors='red')

fig.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# 55% of all security concern cases happened in the month of March 2023 when the spike happened and this proportion is also a lot higher compared to other inquiry types when compared to overall distribution

# %%
# what proportion of pubic sector industry cases are in march 2023 
print(get_spike_props('AccountIndustry', 'Public Sector'))
print(get_spike_props('AccountIndustry', 'Retailer'))
print(get_spike_props('AccountIndustry', 'Information Security'))
print(get_spike_props('AccountIndustry', 'Finance'))
print(get_spike_props('AccountIndustry', 'Technology'))
# Out:
# 0.5094339622641509
# 0.21893491124260356
# 0.14488636363636365
# 0.20245398773006135
# 0.17329545454545456

# %%
march_counts = spike[spike['CreatedMonth'] == '2023-03']['AccountIndustry'].value_counts()

# Get percentages of cases for each priority in March compared to all other months
percentages = []
for priority in march_counts.index:
    percentage = get_spike_props('AccountIndustry', priority) * 100
    percentages.append(percentage)

# Create a DataFrame for plotting
plot_data = pd.DataFrame({'March Counts': march_counts, 'March Percentage': percentages})

# Plotting
fig, ax1 = plt.subplots()

# Bar chart for counts
ax1.bar(plot_data.index, plot_data['March Counts'], color='blue', alpha=0.7, label='March Counts')
ax1.set_xlabel('Priority')
ax1.set_ylabel('Counts', color='blue')
ax1.tick_params('y', colors='blue')
ax1.set_title('March 2023 Cases by Priority Type and Percentage')

# Create a second y-axis for percentages
ax2 = ax1.twinx()
ax2.plot(plot_data.index, plot_data['March Percentage'], color='red', marker='o', label='March Percentage')
ax2.set_ylabel('Percentage', color='red')
ax2.tick_params('y', colors='red')

# Display the legend
fig.tight_layout()
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# One could say that the proportion of public sector cases is high in march due to the overall increase in cases in march however if we look at other proportions, public sector is significantly higher compared to other industries

# %%
# what proportion of 
print(get_spike_props('Priority', 'Critical'))
print(get_spike_props('Priority', 'High'))
print(get_spike_props('Priority', 'Medium'))
print(get_spike_props('Priority', 'Low'))
print(get_spike_props('Priority', 'Very Low'))
# Out:
# 0.38979591836734695
# 0.40618101545253865
# 0.34624697336561744
# 0.21680216802168023
# 0.015060240963855422

# %%
march_counts = spike[spike['CreatedMonth'] == '2023-03']['Priority'].value_counts()

percentages = []
for priority in march_counts.index:
    percentage = get_spike_props('Priority', priority) * 100
    percentages.append(percentage)

plot_data = pd.DataFrame({'March Counts': march_counts, 'March Percentage': percentages})

fig, ax1 = plt.subplots()

ax1.bar(plot_data.index, plot_data['March Counts'], color='#009156', alpha=0.7, label='March Counts')
ax1.set_xlabel('Priority')
ax1.set_ylabel('# Cases', color='#009156')
ax1.tick_params('y', colors='#009156')
ax1.set_title('March 2023 Cases by Priority Type')

ax2 = ax1.twinx()
ax2.plot(plot_data.index, plot_data['March Percentage'], color='#FC7786', marker='o', label='% March Cases')
ax2.set_ylabel('% Cases', color='#FC7786')
ax2.tick_params('y', colors='#FC7786')

fig.tight_layout()
plt.legend()
plt.show()

# %%
# Get counts of cases by priority in March
march_counts = spike[spike['CreatedMonth'] == '2023-03']['Priority'].value_counts()

# Get percentages of cases for each priority in March compared to all other months
percentages = []
for priority in march_counts.index:
    percentage = get_spike_props('Priority', priority) * 100
    percentages.append(percentage)

# Create a DataFrame for plotting
plot_data = pd.DataFrame({'March Counts': march_counts, 'March Percentage': percentages})

# Plotting a grouped bar chart
fig, ax = plt.subplots(figsize=(10,6))

bar_width = 0.35
index = range(len(plot_data))

# Bar chart for counts
bars1 = ax.bar(index, plot_data['March Counts'], bar_width, label='March Counts', color='blue', alpha=0.7)

# Bar chart for percentages
bars2 = ax.bar([i + bar_width for i in index], plot_data['March Percentage'], bar_width, label='March Percentage', color='red', alpha=0.7)

# X-axis labels
ax.set_xticks([i + bar_width/2 for i in index])
ax.set_xticklabels(plot_data.index)

# Y-axis labels
ax.set_ylabel('Counts')
ax2 = ax.twinx()
ax2.set_ylabel('Percentage')

# Display the legend
ax.legend(loc='upper left')
ax2.legend(loc='upper right')

# Title
ax.set_title('March 2023 Cases by Priority Type and Percentage')

# Show the plot
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Why is the proportion for very low priority cases especially low in March 2023

# %% [markdown]
# # Time Series by Feature

# %% [markdown]
# Based on our distribution differences and proportions, we want to look into 3 features that had a major difference in the March 2023 cases compared to other months:
# * Security Concern Inquiry Type
# * Public Sector Account Industry
# * Very Low Priority
#
# >Need to graph the proportions of that condition per each month to standardize the fact that March 2023 also had a higher number of cases in general

# %%
# security concern inquiry type
sc_proportions = df[df['InquiryType'] == 'Security Concern'].pivot_table(index='CreatedMonth', aggfunc='size') / df.groupby('CreatedMonth').size()
sc_proportions = sc_proportions.fillna(0)

# %%
sc_proportions.plot()
# Out:
# <AxesSubplot:xlabel='CreatedMonth'>

# %% [markdown]
# Even though there are drastic fluctuations with the security concern cases per month, there is still a significant spike seen in March 2023 leading to the possibility that some vulnerability was exposed in a product that month

# %%
# public sector account industry 
ps_proportions = df[df['AccountIndustry'] == 'Public Sector'].pivot_table(index='CreatedMonth', aggfunc='size') / df.groupby('CreatedMonth').size()
ps_proportions = ps_proportions.fillna(0)

# %%
ps_proportions.plot()
# Out:
# <AxesSubplot:xlabel='CreatedMonth'>

# %%
# very low priority
vlp_proportions = df[df['Priority'] == 'Very Low'].pivot_table(index='CreatedMonth', aggfunc='size') / df.groupby('CreatedMonth').size()
vlp_proportions = vlp_proportions.fillna(0)

# %%
vlp_proportions.plot()
# Out:
# <AxesSubplot:xlabel='CreatedMonth'>

# %%
df
# Out:
#        Number         CreatedDate  Priority Account          ACV  \
# 0     CS96304 2020-01-01 02:30:00  Very Low     142  10125545.34
# 1     CS71638 2020-01-02 19:10:00      High     154    873271.83
# 2     CS44369 2020-01-04 04:50:00      High     127  11961103.07
# 3     CS61103 2020-01-05 02:01:00  Critical     179  64658626.07
# 4     CS67928 2020-01-05 03:08:00      High     115  16274282.36
# ...       ...                 ...       ...     ...          ...
# 2052  CS88712 2023-07-23 10:13:00  Critical     149  39219548.74
# 2053  CS33799 2023-07-23 21:52:00  Critical      25   4211894.37
# 2054  CS69674 2023-07-25 00:17:00  Very Low     226   3750328.78
# 2055  CS80200 2023-07-26 17:29:00       Low     119  48217327.48
# 2056  CS96284 2023-07-28 11:21:00      High     165  17260639.22
#
#       UpcomingACVOpportunities  AccountCountry       AccountIndustry  \
# 0                   -121800.28  United Kingdom              Retailer
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
# Selecting the independent and dependent variables
X = df[['Priority', 'AccountCountry', 'AccountIndustry', 'CreatedMonth', 'InquiryType']]
y = df['ACV']

# Convert categorical variables to numerical representations
X_encoded = X.copy()
for column in X.select_dtypes(include=['object']).columns:
    X_encoded[column] = X[column].astype('category').cat.codes

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Create a Random Forest Regressor model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
rf_model.fit(X_train, y_train)

# Get feature importances from the trained model
feature_importances = rf_model.feature_importances_

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({'Feature': X_encoded.columns, 'Importance': feature_importances})

# Sort the DataFrame by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plotting the feature importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.title('Feature Importance from Random Forest Regressor')
plt.show()

# %%
X = df[['Priority', 'AccountCountry', 'AccountIndustry', 'InquiryType']]
y = df['ACV']

# Convert categorical variables to numerical representations
X_encoded = X.copy()
for column in X.select_dtypes(include=['object']).columns:
    X_encoded[column] = X[column].astype('category').cat.codes

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Create a Random Forest Regressor model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
rf_model.fit(X_train, y_train)

# Get feature importances from the trained model
feature_importances = rf_model.feature_importances_

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({'Feature': X_encoded.columns, 'Importance': feature_importances})

# Sort the DataFrame by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plotting the feature importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.title('Feature Importance from Random Forest Regressor')
plt.show()

# %%
X = df[['Priority', 'AccountCountry', 'AccountIndustry', 'InquiryType']]
y = df['UpcomingACVOpportunities']

# Convert categorical variables to numerical representations
X_encoded = X.copy()
for column in X.select_dtypes(include=['object']).columns:
    X_encoded[column] = X[column].astype('category').cat.codes

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Create a Random Forest Regressor model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
rf_model.fit(X_train, y_train)

# Get feature importances from the trained model
feature_importances = rf_model.feature_importances_

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({'Feature': X_encoded.columns, 'Importance': feature_importances})

# Sort the DataFrame by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plotting the feature importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, palette='viridis')
plt.title('Feature Importance from Random Forest Regressor')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Priority', y='ACV', data=df)
plt.title('ACV by Priority')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='InquiryType', y='ACV', data=df)
plt.title('ACV by Inquiry Type')
plt.show()

# %%
plt.figure(figsize=(12, 8))
pivot_table_acv = df.pivot_table(index='AccountCountry', columns='AccountIndustry', values='ACV', aggfunc='mean')
sns.heatmap(pivot_table_acv, annot=True, cmap='viridis', fmt='.0f', linewidths=.5)
plt.title('ACV by Account Country and Industry')
plt.show()

# %%
df.groupby('CreatedMonth').count()['Account'].plot()
# Out:
# <AxesSubplot:xlabel='CreatedMonth'>

# %%
df.groupby('CreatedMonth').mean()['ACV'].plot()
# Out:
# <AxesSubplot:xlabel='CreatedMonth'>

# %%
df.groupby('CreatedMonth').sum()['ACV'].plot()
# Out:
# <AxesSubplot:xlabel='CreatedMonth'>

# %%
# check for any outliers with ACV 
q1 = df['ACV'].quantile(0.25)
q3 = df['ACV'].quantile(0.75)

iqr = q3 - q1
upper = q3 + 1.5 * iqr

high_outliers = df[df['ACV'] > upper]
high_outliers
# Out:
#        Number         CreatedDate  Priority Account          ACV  \
# 75    CS32524 2020-03-13 16:51:00  Very Low     173  75431069.94
# 322   CS67852 2020-11-20 00:34:00  Critical      58  76986619.94
# 502   CS48928 2021-05-26 08:09:00  Critical     173  75431069.94
# 504   CS36115 2021-05-28 10:09:00    Medium     258  73097514.04
# 540   CS40106 2021-07-04 18:00:00  Critical     194  74880571.68
# 560   CS76960 2021-07-22 02:04:00  Critical      58  76986619.94
# 596   CS32792 2021-08-27 12:36:00    Medium     258  73097514.04
# 617   CS35393 2021-09-17 08:27:00  Very Low      58  76986619.94
# 697   CS38210 2021-12-02 02:23:00  Critical     173  75431069.94
# 727   CS16217 2021-12-31 14:42:00  Critical     194  74880571.68
# 793   CS24498 2022-03-09 12:20:00  Very Low     194  74880571.68
# 812   CS44990 2022-03-31 11:15:00  Critical     194  74880571.68
# 818   CS26463 2022-04-07 21:50:00    Medium     173  75431069.94
# ...

# %%
# the accounts with high ACV 
high_outliers['AccountIndustry'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.groupby('Priority').sum()['ACV'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Priority'>

# %%
df.groupby('InquiryType').sum()['ACV'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='InquiryType'>

# %%
df.groupby('AccountIndustry').sum()['ACV'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='AccountIndustry'>

# %%
public_sector_cases = df[df['AccountIndustry'] == 'Public Sector']
proportions = public_sector_cases.groupby(df['CreatedMonth']).size() / df.groupby(df['CreatedMonth']).size()
proportions.plot()
# Out:
# <AxesSubplot:xlabel='CreatedMonth'>

# %%
low_priority_cases = df[df['Priority'] == 'Low']
proportions = low_priority_cases.groupby(df['CreatedMonth']).size() / df.groupby(df['CreatedMonth']).size()
proportions.plot()
# Out:
# <AxesSubplot:xlabel='CreatedMonth'>

# %%
df.groupby('CreatedMonth').sum()['UpcomingACVOpportunities']
# Out:
# CreatedMonth
# 2020-01    2.983241e+07
# 2020-02    2.511565e+07
# 2020-03    3.787519e+07
# 2020-04    3.979782e+07
# 2020-05    1.921679e+07
# 2020-06    2.525952e+07
# 2020-07    1.660145e+07
# 2020-08    2.244753e+07
# 2020-09    1.182186e+07
# 2020-10    2.334689e+07
# 2020-11    1.955964e+07
# 2020-12    1.666594e+07
# 2021-01    1.571323e+07
# 2021-02    2.396912e+07
# 2021-03    2.710638e+07
# 2021-04    3.142634e+07
# 2021-05    1.609644e+07
# 2021-06    2.504692e+07
# 2021-07    2.906830e+07
# 2021-08    1.960935e+07
# 2021-09    1.832859e+07
# 2021-10    2.753121e+07
# 2021-11    2.357253e+07
# 2021-12    2.428423e+07
# 2022-01    1.988464e+07
# 2022-02    2.058121e+07
# 2022-03    2.251551e+07
# 2022-04    1.781021e+07
# 2022-05    2.247400e+07
# 2022-06    1.544253e+07
# 2022-07    2.219725e+07
# 2022-08    1.964638e+07
# 2022-09    2.339970e+07
# 2022-10    2.365904e+07
# 2022-11    1.813703e+07
# 2022-12    1.951707e+07
# 2023-01    2.434923e+07
# ...

# %%
df.groupby('CreatedMonth').sum()['ACV']
# Out:
# CreatedMonth
# 2020-01    5.513546e+08
# 2020-02    6.149239e+08
# 2020-03    8.232905e+08
# 2020-04    5.022915e+08
# 2020-05    5.575907e+08
# 2020-06    6.959526e+08
# 2020-07    7.512505e+08
# 2020-08    6.815616e+08
# 2020-09    5.825498e+08
# 2020-10    5.463376e+08
# 2020-11    6.093799e+08
# 2020-12    7.383024e+08
# 2021-01    7.368389e+08
# 2021-02    5.405415e+08
# 2021-03    4.360436e+08
# 2021-04    4.756772e+08
# 2021-05    7.501898e+08
# 2021-06    6.426859e+08
# 2021-07    8.484427e+08
# 2021-08    7.028884e+08
# 2021-09    5.144657e+08
# 2021-10    7.847384e+08
# 2021-11    6.586802e+08
# 2021-12    6.412856e+08
# 2022-01    5.134033e+08
# 2022-02    5.594269e+08
# 2022-03    6.842238e+08
# 2022-04    8.159077e+08
# 2022-05    9.757593e+08
# 2022-06    4.981159e+08
# 2022-07    4.608325e+08
# 2022-08    6.934220e+08
# 2022-09    7.489241e+08
# 2022-10    8.235738e+08
# 2022-11    8.637562e+08
# 2022-12    8.202582e+08
# 2023-01    6.173214e+08
# ...

# %%
spike[spike['UpcomingACVOpportunities']<0]['Priority'].value_counts()
# Out:
# Critical    42
# High        37
# Medium      32
# Low         22
# Very Low     1
# Name: Priority, dtype: int64

# %%
spike[spike['UpcomingACVOpportunities']>0]['Priority'].value_counts()
# Out:
# Critical    149
# High        147
# Medium      111
# Low          58
# Very Low      4
# Name: Priority, dtype: int64

# %%
sns.boxplot(y='')
